# %%
import pandas as pd
import numpy as np

# %%
a = [3,4,21,1,1,2,3]
a[0:3]
# Out:
# [3, 4, 21]

# %%
# assuming array is your 3D numpy array with shape (3, 4, 2)
data = np.random.rand(3, 4, 6)

# reshape the array to a 2D array with shape (3, 4*2)
data_reshaped = data.reshape(3, -1)

# %%
data = np.random.rand(3 * 4 * 6)

# %%
data_reshaped
# Out:
# array([[0.9166964 , 0.47710886, 0.16042115, 0.72148226, 0.58051426,
#         0.22416859, 0.04450233, 0.20758651, 0.18892944, 0.76300465,
#         0.35998576, 0.90794732, 0.57215449, 0.98105907, 0.75392738,
#         0.3345828 , 0.29118624, 0.91815653, 0.21336902, 0.08053641,
#         0.83413417, 0.5052542 , 0.10799285, 0.08512989],
#        [0.99396877, 0.33700027, 0.11628209, 0.40384653, 0.03860992,
#         0.1613619 , 0.69090504, 0.71122448, 0.34452018, 0.15777441,
#         0.82329624, 0.38533059, 0.55255636, 0.55906265, 0.59901869,
#         0.61581981, 0.45143093, 0.1903057 , 0.67650057, 0.31170579,
#         0.94879515, 0.47411766, 0.05528082, 0.76765389],
#        [0.2581759 , 0.90969619, 0.49215699, 0.15161487, 0.46187112,
#         0.90099308, 0.94276238, 0.54855121, 0.00740746, 0.73509273,
#         0.92538767, 0.61084937, 0.1832488 , 0.33981888, 0.11485028,
#         0.53878585, 0.40845821, 0.89653388, 0.963151  , 0.70915728,
#         0.76317777, 0.42881567, 0.07446032, 0.56317099]])

# %%
companies = ['A','B', 'C','D' , 'E','F']
dates = ['Enero', 'Febrero', 'Marzo']

# %%
n_companies = len(companies)
n_dates = len(dates)
n_char = 4

# %%
chars = ['x_' + str(i) for i in range(n_char)]

# %%
dates_indices = np.tile(np.repeat(dates, n_char), n_companies)

print(len(dates_indices))
dates_indices
# Out:
# 72
# array(['Enero', 'Enero', 'Enero', 'Enero', 'Febrero', 'Febrero',
#        'Febrero', 'Febrero', 'Marzo', 'Marzo', 'Marzo', 'Marzo', 'Enero',
#        'Enero', 'Enero', 'Enero', 'Febrero', 'Febrero', 'Febrero',
#        'Febrero', 'Marzo', 'Marzo', 'Marzo', 'Marzo', 'Enero', 'Enero',
#        'Enero', 'Enero', 'Febrero', 'Febrero', 'Febrero', 'Febrero',
#        'Marzo', 'Marzo', 'Marzo', 'Marzo', 'Enero', 'Enero', 'Enero',
#        'Enero', 'Febrero', 'Febrero', 'Febrero', 'Febrero', 'Marzo',
#        'Marzo', 'Marzo', 'Marzo', 'Enero', 'Enero', 'Enero', 'Enero',
#        'Febrero', 'Febrero', 'Febrero', 'Febrero', 'Marzo', 'Marzo',
#        'Marzo', 'Marzo', 'Enero', 'Enero', 'Enero', 'Enero', 'Febrero',
#        'Febrero', 'Febrero', 'Febrero', 'Marzo', 'Marzo', 'Marzo',
#        'Marzo'], dtype='<U7')

# %%
char_indices = np.tile(chars, n_dates * n_companies)
print(len(char_indices))
char_indices
# Out:
# 72
# array(['x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0',
#        'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1',
#        'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2',
#        'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3',
#        'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0',
#        'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1',
#        'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2',
#        'x_3', 'x_0', 'x_1', 'x_2', 'x_3', 'x_0', 'x_1', 'x_2', 'x_3'],
#       dtype='<U3')

# %%
company_indices = np.repeat(companies, n_dates * n_char)
print(len(company_indices))
company_indices
# Out:
# 72
# array(['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'D', 'D', 'D',
#        'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'E', 'E', 'E', 'E',
#        'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'F', 'F', 'F', 'F', 'F',
#        'F', 'F', 'F', 'F', 'F', 'F', 'F'], dtype='<U1')

# %%
len(data)
# Out:
# 72

# %%
df = pd.DataFrame({'Date': dates_indices,'Characteristic': char_indices,'Value': data, 'Stock': company_indices,})

df
# Out:
#        Date Characteristic     Value Stock
# 0     Enero            x_0  0.446316     A
# 1     Enero            x_1  0.052443     A
# 2     Enero            x_2  0.381014     A
# 3     Enero            x_3  0.821167     A
# 4   Febrero            x_0  0.973965     A
# ..      ...            ...       ...   ...
# 67  Febrero            x_3  0.149291     F
# 68    Marzo            x_0  0.197573     F
# 69    Marzo            x_1  0.089611     F
# 70    Marzo            x_2  0.067655     F
# 71    Marzo            x_3  0.318274     F
#
# [72 rows x 4 columns]

# %%
# Pivot DataFrame
df_pivot = df.pivot_table(index=['Stock', 'Date'],
                          columns='Characteristic',
                          values='Value')

# Reset index for a flat DataFrame
df_pivot.reset_index(inplace=True)

df_pivot
# Out:
# Characteristic Stock     Date       x_0       x_1       x_2       x_3
# 0                  A    Enero  0.446316  0.052443  0.381014  0.821167
# 1                  A  Febrero  0.973965  0.962864  0.270067  0.818238
# 2                  A    Marzo  0.678627  0.176247  0.109405  0.928592
# 3                  B    Enero  0.001228  0.874539  0.049691  0.460532
# 4                  B  Febrero  0.569619  0.460759  0.770713  0.017377
# 5                  B    Marzo  0.941031  0.141639  0.354326  0.045421
# 6                  C    Enero  0.524903  0.034585  0.575482  0.893106
# 7                  C  Febrero  0.099162  0.187970  0.797405  0.189574
# 8                  C    Marzo  0.868927  0.561111  0.645738  0.468726
# 9                  D    Enero  0.930958  0.891035  0.037553  0.529256
# 10                 D  Febrero  0.151428  0.876430  0.069310  0.622739
# 11                 D    Marzo  0.865675  0.400028  0.834995  0.486745
# 12                 E    Enero  0.406105  0.094043  0.581472  0.256667
# 13                 E  Febrero  0.566760  0.239067  0.599292  0.517251
# 14                 E    Marzo  0.458918  0.763396  0.093779  0.443569
# 15                 F    Enero  0.592939  0.049649  0.591519  0.896981
# 16                 F  Febrero  0.718992  0.694127  0.986143  0.149291
# 17                 F    Marzo  0.197573  0.089611  0.067655  0.318274
